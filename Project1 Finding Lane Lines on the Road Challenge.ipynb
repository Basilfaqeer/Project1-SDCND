# %% [markdown]
# <h1> Project 1: Finding Lane Lines on the Road </h1>                               <h1> Basil Omar ALfaqeer </h1>
# <h1> Challenge </h1>
# <ul>Tools :
# <li>Color Selection</li>
# <li>Grayscaling</li>
# <li>Gaussian Smoothing</li>
# <li>Canny edge detection</li>
# <li>Region of interest selection</li>
# <li>Hough Transform line detection</li>
# </ul>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Gaussian Blur
def apply_gaussian_blur(gray, kernel_size = 5):
    return gaussian_blur(gray, kernel_size)

# %% [markdown]
# Next we define parameters for the Canny function, which will take in an image, a low_threshold, and a high_threshold
# <li>pixel values below low_threshold are discarded</li>
# <li>pixel values above high_threshold are considered to be edges</li>
# <li>pixel values between low and high thresholds are kept if they are touching a pixel above high threshold (edges)</li>
#
# <h3>Canny Input</h3><h5>blur_gray (shape: (540,960)</h5>
# <h3>Canny Output</h3><h5>edges (shape:(540, 960) </h5>

# %%
# Define Parameters for Canny
def apply_canny(blur_gray, low_threshold = 75, high_threshold = 255):
    # Apply Canny, changes pixel values to be either 0 (black) or 255 (white)
    return canny(blur_gray, low_threshold, high_threshold)

# %% [markdown]
# <h3>Image Mask / Region of interest</h3>
# <p>Next we wish to apply an image mask to only consider lane lines in a surrounding polygon</p>
# <p>Here we will use the <strong>cv2.fillPoly(mask, vertices, ignore_mask_color) function </strong></p>
# <li>Input edges shape: (540, 960) Output: masked Image shape: (540, 960) </li>
# <li>Function does not change input 'edges'</li>

# %%
def apply_mask(edges, image, gray):
    #make general shape of mask
    mask = np.zeros_like(edges)
    
    # create ignore mask color = 255
    ignore_mask_color = 255 

    # create vertices for region
    imshape = image.shape

    ysize = image.shape[0]
    xsize = image.shape[1]
    
    x_middle = xsize/2
    x_offset = 80
    
    y_middle = ysize/2
    y_offset = 90
    vertices = np.array([[(0, ysize),
                         (x_middle - x_offset, y_middle + y_offset),
                         (x_middle + x_offset, y_middle + y_offset),
                         (xsize, ysize)]], dtype=np.int32)
    

    # Polyfill the mask and do a bitwise_and to keep only edges in the region
    (masked_image, mask) = region_of_interest(edges, vertices)
    return masked_image

def plot_mask(edges, image, masked_image):
    # PLOT
    fig = plt.figure()

    a = fig.add_subplot(3,1,1)
    edgeplot = plt.imshow(edges, cmap="gray")
    a.set_title('Edges')

    a = fig.add_subplot(3,1,2)
    a.set_title('Image')
    edgeplot = plt.imshow(image)

    a = fig.add_subplot(3,1,3)
    a.set_title('Masked Image')
    edgeplot = plt.imshow(masked_image, cmap="gray")
    plt.show()

# %% [markdown]
# <h3>Hough Lines</h3>
# <li>Now that we have masked image Shape: (540, 960). We can use <strong>lines = cv2.HoughLinesP(masked_edges, rho, theta, threshold, np.array([]), min_line_length, max_line_gap)</strong> to get a row vector of our lines</li>
# <li>Copy the image to draw on <strong>line_image</strong> (row vecto with (x1,y1,x2,y2) as elements).</li>
# <li>Iterate through the rows of lines, then grab each element (x1, y1, x2, and y2) and use <strong>cv2.line(<strong>line_image</strong>, pt1, pt2, color, thickness)</strong> to draw lines</li>

# %%
def apply_hough(masked_image):
    theta = np.pi/180     
    rho = 1.89
    threshold = 60
    
    min_line_len = 60
    max_line_gap = 200

    # Create a line image with hough lines on it
    hough_image, lines = hough_lines(masked_image, rho, theta, threshold, min_line_len, max_line_gap)

#     print('lines: ', lines.shape)
    # line_zero[:,1,0] = lines[:,1,0]

    return hough_image, lines
    # We gave line_image color when we copied the shape of mask_image and then added a 3rd dimension for our color space.
    # Then in draw_lines we input color = [255, 0, 0] so that will be red in this case. 
    # I changed the input color in draw_lines to [0, 255, 0] so we get green 

def plot_hough(hough_image, lines):
    fig = plt.figure()

    b = fig.add_subplot(2,1,1)
    edgeplot = plt.imshow(lines)
    b.set_title('Lines')

    b = fig.add_subplot(2,2,2)
    b.set_title('Hough Image')
    edgeplot = plt.imshow(hough_image)
    plt.show()

# %% [markdown]
# Now we have the line image. And we have the masked image/masked edges
# The next step is to draw the line_image ontop of the masked_image
# <li>Shape of masked_image: (540, 960)</li>
# <li>Shape of line_image: (540,960, 3)...This one has color</li>
# <h5>Plot of line image vs mask image</h5>

# %%
def plot_mask_and_hough(masked_image, hough_image):
    fig = plt.figure()
    c = fig.add_subplot(1,2,1)
    edgeplot = plt.imshow(masked_image, cmap="gray")
    c.set_title('masked_image')

    c = fig.add_subplot(1,2,2)
    c.set_title('Hough_image')
    edgeplot = plt.imshow(hough_image)
    plt.show()

# %%
# Img is the output of hough lines ==> lines_image
# initial_image is the color_edges, which is the initial edges image with a 3rd dimension for color
# Edges shape: (540, 960)
def apply_lines_edges_weighted(image, edges, hough_image):
    lines_edges_weighted = weighted_img(hough_image, image)
    return lines_edges_weighted

def plot_lines_edges_weighted_hough_and_original():
    # PLOT
    fig = plt.figure()
    d = fig.add_subplot(3,1,1)
    line_edgeplot = plt.imshow(hough_image)
    d.set_title('hough_image')

    d = fig.add_subplot(3,1,2)
    line_edgeplot = plt.imshow(color_edges)
    d.set_title('color_edges')

    d = fig.add_subplot(3,1,3)
    line_edgeplot = plt.imshow(lines_edges_weighted)
    d.set_title('lines_edges_weighted')

    plt.show()
    
def plot_weighted_image(lines_edges_weighted):
    plt.imshow(lines_edges_weighted)

# %%
# Converts image to grayscale
def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Applies canny transform
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

# Applies gaussian noise kernel, typically use kernel size of 3 or 5. (odd numbers only)
def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)

    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:  #if it is 3 or 4 channels; RGB or RGBT
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count  #so you can fill multiple colors
    else:
        ignore_mask_color = 255

    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)

    #returning the image only where mask pixels are nonzero
    # Because we just filled the mask matrix with vertices in the *fillPoly* function.
    masked_image = cv2.bitwise_and(img, mask)
    return (masked_image, mask)


def draw_lines(img, lines, color=[255, 0, 0], thickness=12):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    x1_values = lines[:, :, 0]
    y1_values = lines[:, :, 1]
    x2_values = lines[:, :, 2]
    y2_values = lines[:, :, 3]


    global prev_left_x_min
    global prev_left_x_max
    global prev_right_x_min
    global prev_right_x_max

    y_max = max(np.amax(y1_values), np.amax(y2_values))
    y_min = max(np.amin(y1_values), np.amin(y2_values))
    left_slopes = []
    right_slopes = []

    right_lane = []
    left_lane = []

    for line in lines:
        for x1, y1, x2, y2 in line:
            slope = (y2 - y1) / (x2 - x1)

#             if slope < 0:  #left lane has negative slope
            if (-0.9 < slope < -0.6):
                left_slopes.append(slope)
                left_lane.append(line)
            elif 0.45 < slope < 0.7: # right lane positive slope
                right_slopes.append(slope)
                right_lane.append(line)

    left_slopes_arr = np.array(left_slopes)
    right_slopes_arr = np.array(right_slopes)

    left_lines_arr = np.array(left_lane)
    right_lines_arr = np.array(right_lane)

    # Find average slopes
    left_lane_slope_average = np.mean(left_slopes_arr)  # type numpy.float64
    right_lane_slope_average = np.mean(right_slopes_arr)

    y_max = int(y_max)
    y_min = int(y_min)

    if len(left_lines_arr) > 0:
        # Compute Left lane intercept:
        y_intercept_left_lane_average = np.mean(left_lines_arr[:, :, 1] - (left_lines_arr[:, :, 0] * left_lane_slope_average))

        # Compute Left lane Xmax and Xmin:
        x_max_left = int((y_max - y_intercept_left_lane_average) / left_lane_slope_average)
        x_min_left = int((y_min - y_intercept_left_lane_average) / left_lane_slope_average)
            

        cv2.line(img, (x_max_left, y_max), (x_min_left, y_min), color, thickness)
        # Save last coordinates to keep line going
        
        prev_left_x_max = x_max_left
        prev_left_x_min = x_min_left

    else:
        
        if prev_left_x_max is not None:
            print('prev_left_x_max is not None')
            cv2.line(img, (prev_left_x_max, y_max),(prev_left_x_min, y_min), color, thickness)
        else:
            print('nothing')
            
    if len(right_lines_arr) > 0:
        # Compute Right Lane Intercept:
        y_intercept_right_lane_average = np.mean(right_lines_arr[:, :, 1] - (right_lines_arr[:, :, 0] * right_lane_slope_average))

        # Compute Right lane Xmax and Xmin:
        x_max_right = int((y_max - y_intercept_right_lane_average) / right_lane_slope_average)
        x_min_right = int((y_min - y_intercept_right_lane_average) / right_lane_slope_average)

        cv2.line(img, (x_max_right, y_max), (x_min_right, y_min), color, thickness)
        prev_right_x_max = x_max_right
        prev_right_x_min = x_min_right
    else:
        if prev_right_x_max is not None:
            print('prev_right_x_max is not NONE')
#         print("right_lines_arr is empty. Not drawing anything as there are no lines to choose from.")
            cv2.line(img, (prev_right_x_max, y_max), (prev_right_x_min, y_min), color, thickness)
        else:
            
            print('nothing right side empty')




def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        img shape will be 2D output from canny transform
    Returns an image with hough lines drawn.
    """
    hough_lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len,
                                  maxLineGap=max_line_gap)

    # Create a line_img which we will ultimately draw on in our draw lines function
    # line_img will become zeros (540, 960, 3). 
    line_img = np.zeros((*img.shape, 3), dtype=np.uint8)  #*before img.shape unpacks the tuple

    draw_lines(line_img, hough_lines)
    return (line_img, hough_lines)

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# <h1>Video Processing:</h1>

# %%
# Save previous coordinates as global variables in case I don't detect any lines on the current frame
prev_left_x_min = None
prev_left_x_max = None
prev_right_x_min = None
prev_right_x_max = None

# %%
def process_image(image):
    gray = grayscale(image)
    blur_gray = apply_gaussian_blur(gray)
    edges = apply_canny(blur_gray)
    masked_image = apply_mask(edges, image, gray)
    hough_image, lines = apply_hough(masked_image)
    lines_edges_weighted = apply_lines_edges_weighted(image, edges, hough_image)
    return lines_edges_weighted

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %% [markdown]
# <h1>Challenge</h1>

# %%
white_output = 'challenge.mp4'
clip1 = VideoFileClip("challenge.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# MoviePy: building video file challenge.mp4
# ----------------------------------------
#
# Writing video into challenge.mp4
# |----------| 0/241   0% [elapsed: 00:00 left: ?, ? iters/sec]
# C:\Users\basil\Miniconda3\envs\carnd-term1\lib\site-packages\moviepy\audio\io\readers.py:110: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.nchannels))
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 4/251, at time 0.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 5/251, at time 0.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |----------| 6/241   2% [elapsed: 00:00 left: 00:19, 11.90 iters/sec]
# C:\Users\basil\Miniconda3\envs\carnd-term1\lib\site-packages\numpy\core\_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# C:\Users\basil\Miniconda3\envs\carnd-term1\lib\site-packages\numpy\core\_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 6/251, at time 0.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 7/251, at time 0.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 8/251, at time 0.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 9/251, at time 0.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 10/251, at time 0.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 11/251, at time 0.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |----------| 12/241   4% [elapsed: 00:01 left: 00:19, 11.66 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 12/251, at time 0.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 13/251, at time 0.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 14/251, at time 0.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 15/251, at time 0.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 16/251, at time 0.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |----------| 17/241   7% [elapsed: 00:01 left: 00:21, 10.36 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 17/251, at time 0.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 18/251, at time 0.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 19/251, at time 0.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 20/251, at time 0.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 21/251, at time 0.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |----------| 22/241   9% [elapsed: 00:02 left: 00:22,  9.88 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 22/251, at time 0.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 23/251, at time 0.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 25/251, at time 1.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 26/251, at time 1.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 27/251, at time 1.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 28/251, at time 1.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#---------| 28/241  11% [elapsed: 00:02 left: 00:21,  9.95 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 29/251, at time 1.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 30/251, at time 1.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 31/251, at time 1.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 32/251, at time 1.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 33/251, at time 1.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#---------| 33/241  13% [elapsed: 00:03 left: 00:21,  9.74 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 34/251, at time 1.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 35/251, at time 1.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 36/251, at time 1.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 37/251, at time 1.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 38/251, at time 1.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#---------| 38/241  15% [elapsed: 00:03 left: 00:21,  9.62 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 39/251, at time 1.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 40/251, at time 1.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 41/251, at time 1.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 42/251, at time 1.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 43/251, at time 1.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#---------| 43/241  17% [elapsed: 00:04 left: 00:20,  9.50 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 44/251, at time 1.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 45/251, at time 1.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 46/251, at time 1.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 47/251, at time 1.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 48/251, at time 1.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 50/251, at time 2.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |##--------| 49/241  20% [elapsed: 00:05 left: 00:20,  9.33 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 51/251, at time 2.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 52/251, at time 2.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 53/251, at time 2.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 54/251, at time 2.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |##--------| 53/241  21% [elapsed: 00:05 left: 00:20,  9.15 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 55/251, at time 2.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 56/251, at time 2.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 57/251, at time 2.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 58/251, at time 2.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |##--------| 57/241  23% [elapsed: 00:06 left: 00:20,  9.01 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 59/251, at time 2.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 60/251, at time 2.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 61/251, at time 2.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 62/251, at time 2.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 63/251, at time 2.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 64/251, at time 2.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |##--------| 63/241  26% [elapsed: 00:06 left: 00:19,  9.17 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 65/251, at time 2.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 66/251, at time 2.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 67/251, at time 2.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 68/251, at time 2.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 69/251, at time 2.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |##--------| 68/241  28% [elapsed: 00:07 left: 00:18,  9.13 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 70/251, at time 2.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 71/251, at time 2.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 72/251, at time 2.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 73/251, at time 2.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 75/251, at time 3.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |###-------| 73/241  30% [elapsed: 00:08 left: 00:18,  9.08 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 76/251, at time 3.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 77/251, at time 3.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 78/251, at time 3.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 79/251, at time 3.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 80/251, at time 3.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 81/251, at time 3.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |###-------| 79/241  32% [elapsed: 00:08 left: 00:17,  9.13 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 82/251, at time 3.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 83/251, at time 3.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 84/251, at time 3.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 85/251, at time 3.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 86/251, at time 3.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 87/251, at time 3.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 88/251, at time 3.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |###-------| 86/241  35% [elapsed: 00:09 left: 00:16,  9.32 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 89/251, at time 3.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 90/251, at time 3.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 91/251, at time 3.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 92/251, at time 3.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |###-------| 90/241  37% [elapsed: 00:09 left: 00:16,  9.24 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 93/251, at time 3.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 94/251, at time 3.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 95/251, at time 3.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 96/251, at time 3.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |###-------| 94/241  39% [elapsed: 00:10 left: 00:16,  9.04 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 97/251, at time 3.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 98/251, at time 3.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 100/251, at time 4.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 101/251, at time 4.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 102/251, at time 4.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |####------| 99/241  41% [elapsed: 00:11 left: 00:16,  8.71 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 103/251, at time 4.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 104/251, at time 4.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 105/251, at time 4.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 106/251, at time 4.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 107/251, at time 4.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |####------| 104/241  43% [elapsed: 00:12 left: 00:16,  8.53 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 108/251, at time 4.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 109/251, at time 4.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 110/251, at time 4.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 111/251, at time 4.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |####------| 108/241  44% [elapsed: 00:12 left: 00:15,  8.31 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 112/251, at time 4.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 113/251, at time 4.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 114/251, at time 4.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 115/251, at time 4.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 116/251, at time 4.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |####------| 113/241  46% [elapsed: 00:13 left: 00:15,  8.36 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 117/251, at time 4.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 118/251, at time 4.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 119/251, at time 4.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |####------| 116/241  48% [elapsed: 00:14 left: 00:15,  8.25 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 120/251, at time 4.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 121/251, at time 4.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 122/251, at time 4.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |####------| 119/241  49% [elapsed: 00:14 left: 00:15,  8.10 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 123/251, at time 4.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 125/251, at time 5.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 126/251, at time 5.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#####-----| 122/241  50% [elapsed: 00:15 left: 00:14,  7.97 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 127/251, at time 5.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 128/251, at time 5.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 129/251, at time 5.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 130/251, at time 5.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 131/251, at time 5.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#####-----| 127/241  52% [elapsed: 00:15 left: 00:14,  7.99 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 132/251, at time 5.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 133/251, at time 5.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 134/251, at time 5.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 135/251, at time 5.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#####-----| 131/241  54% [elapsed: 00:16 left: 00:13,  7.99 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 136/251, at time 5.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 137/251, at time 5.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 138/251, at time 5.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 139/251, at time 5.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#####-----| 135/241  56% [elapsed: 00:17 left: 00:13,  7.85 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 140/251, at time 5.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 141/251, at time 5.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 142/251, at time 5.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 143/251, at time 5.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 144/251, at time 5.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#####-----| 140/241  58% [elapsed: 00:17 left: 00:12,  7.85 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 145/251, at time 5.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 146/251, at time 5.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 147/251, at time 5.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 148/251, at time 5.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#####-----| 144/241  59% [elapsed: 00:18 left: 00:12,  7.83 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 150/251, at time 6.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 151/251, at time 6.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 152/251, at time 6.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 147/241  60% [elapsed: 00:19 left: 00:12,  7.67 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 153/251, at time 6.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 154/251, at time 6.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 155/251, at time 6.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 156/251, at time 6.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 151/241  62% [elapsed: 00:19 left: 00:11,  7.67 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 157/251, at time 6.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 158/251, at time 6.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 153/241  63% [elapsed: 00:20 left: 00:11,  7.55 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 159/251, at time 6.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 160/251, at time 6.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 161/251, at time 6.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 156/241  64% [elapsed: 00:20 left: 00:11,  7.50 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 162/251, at time 6.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 163/251, at time 6.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 164/251, at time 6.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 165/251, at time 6.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 160/241  66% [elapsed: 00:21 left: 00:10,  7.50 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 166/251, at time 6.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 167/251, at time 6.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 168/251, at time 6.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 163/241  67% [elapsed: 00:21 left: 00:10,  7.41 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 169/251, at time 6.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 170/251, at time 6.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 171/251, at time 6.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 172/251, at time 6.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 173/251, at time 6.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |######----| 168/241  69% [elapsed: 00:22 left: 00:09,  7.40 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 175/251, at time 7.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 176/251, at time 7.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 177/251, at time 7.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 178/251, at time 7.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#######---| 172/241  71% [elapsed: 00:23 left: 00:09,  7.41 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 179/251, at time 7.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 180/251, at time 7.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#######---| 174/241  72% [elapsed: 00:23 left: 00:09,  7.28 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 181/251, at time 7.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 182/251, at time 7.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 183/251, at time 7.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 184/251, at time 7.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 185/251, at time 7.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#######---| 179/241  74% [elapsed: 00:24 left: 00:08,  7.33 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 186/251, at time 7.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 187/251, at time 7.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 188/251, at time 7.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 189/251, at time 7.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 190/251, at time 7.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#######---| 184/241  76% [elapsed: 00:24 left: 00:07,  7.37 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 191/251, at time 7.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 192/251, at time 7.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 193/251, at time 7.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 194/251, at time 7.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#######---| 188/241  78% [elapsed: 00:25 left: 00:07,  7.35 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 195/251, at time 7.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 196/251, at time 7.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 197/251, at time 7.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 198/251, at time 7.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#######---| 192/241  79% [elapsed: 00:26 left: 00:06,  7.36 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 200/251, at time 8.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 201/251, at time 8.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 202/251, at time 8.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |########--| 195/241  80% [elapsed: 00:26 left: 00:06,  7.29 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 203/251, at time 8.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 204/251, at time 8.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 205/251, at time 8.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 206/251, at time 8.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |########--| 199/241  82% [elapsed: 00:27 left: 00:05,  7.29 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 207/251, at time 8.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 208/251, at time 8.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 209/251, at time 8.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |########--| 202/241  83% [elapsed: 00:27 left: 00:05,  7.23 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 210/251, at time 8.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 211/251, at time 8.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 212/251, at time 8.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 213/251, at time 8.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 214/251, at time 8.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |########--| 207/241  85% [elapsed: 00:28 left: 00:04,  7.23 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 215/251, at time 8.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 216/251, at time 8.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 217/251, at time 8.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 218/251, at time 8.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 219/251, at time 8.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |########--| 212/241  87% [elapsed: 00:29 left: 00:04,  7.25 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 220/251, at time 8.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 221/251, at time 8.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 222/251, at time 8.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |########--| 215/241  89% [elapsed: 00:29 left: 00:03,  7.22 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 223/251, at time 8.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 225/251, at time 9.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 226/251, at time 9.04/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#########-| 218/241  90% [elapsed: 00:30 left: 00:03,  7.16 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 227/251, at time 9.08/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 228/251, at time 9.12/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 229/251, at time 9.16/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 230/251, at time 9.20/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 231/251, at time 9.24/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#########-| 223/241  92% [elapsed: 00:31 left: 00:02,  7.16 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 232/251, at time 9.28/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 233/251, at time 9.32/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 234/251, at time 9.36/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 235/251, at time 9.40/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#########-| 227/241  94% [elapsed: 00:31 left: 00:01,  7.16 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 236/251, at time 9.44/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 237/251, at time 9.48/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 238/251, at time 9.52/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#########-| 230/241  95% [elapsed: 00:32 left: 00:01,  7.13 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 239/251, at time 9.56/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 240/251, at time 9.60/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 241/251, at time 9.64/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 242/251, at time 9.68/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#########-| 234/241  97% [elapsed: 00:32 left: 00:00,  7.13 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 243/251, at time 9.72/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 244/251, at time 9.76/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 245/251, at time 9.80/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 246/251, at time 9.84/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 247/251, at time 9.88/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# |#########-| 239/241  99% [elapsed: 00:33 left: 00:00,  7.12 iters/sec]Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 248/251, at time 9.92/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Warning: in file challenge.mp4, 2764800 bytes wanted but 0 bytes read,at frame 250/251, at time 10.00/10.04 sec. Using the last valid frame instead.
# prev_right_x_max is not NONE
# Done writing video in challenge.mp4 !
# Your video is ready !
# Wall time: 36 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
